# %%
import pandas as pd 

df_parques = pd.read_csv('~/Coding/UNSAM/Data/arbolado-en-espacios-verdes.csv')
df_veredas = pd.read_csv('~/Coding/UNSAM/Data/arbolado-publico-lineal-2017-2018.csv')
# Out:
# C:\Users\matye\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3155: DtypeWarning: Columns (2,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_tipas_parques = df_parques[df_parques['nombre_cie']=="Tipuana Tipu"][['diametro','altura_tot']].copy()

df_tipas_veredas = df_veredas[df_veredas['nombre_cientifico']=="Tipuana tipu"][['diametro_altura_pecho','altura_arbol']].copy()

# %%
df_tipas_parques.shape
# Out:
# (4031, 2)

# %%
df_tipas_veredas.shape
# Out:
# (9330, 2)

# %%
amb_parq = ['parque' for i in range(df_tipas_parques.shape[0])]
amb_ver = ['vereda' for i in range(df_tipas_veredas.shape[0])]

df_tipas_parques['ambiente'] = amb_parq
df_tipas_veredas['ambiente'] = amb_ver

# %%
headers = ['diam', 'alt', 'ambiente']
df_tipas_parques.columns = headers
df_tipas_veredas.columns = headers

# %%
df_tipas = pd.concat([df_tipas_veredas, df_tipas_parques], ignore_index=True)

df_tipas.head()
# Out:
#     diam   alt ambiente
# 0   88.0  34.0   vereda
# 1  108.0  17.0   vereda
# 2   80.0  16.0   vereda
# 3  107.0  25.0   vereda
# 4   80.0  22.0   vereda

# %%
import seaborn as sns

df_tipas.boxplot('diam', by = 'ambiente')
# Out:
# <AxesSubplot:title={'center':'diam'}, xlabel='ambiente'>

# %%
df_tipas.boxplot('alt', by = 'ambiente')
# Out:
# <AxesSubplot:title={'center':'alt'}, xlabel='ambiente'>
